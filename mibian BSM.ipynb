# %% [markdown]
# # Calculating Implied Volatality for NIFTY Options

# %%
import pandas as pd
import numpy as np
from mibian import BS
import mibian as mb

# %%
data = pd.read_csv(r'C:\Users\SARVESH\Documents\GitHub\home-credit-default\OptionData.csv')

# %%
data['IV for CALL'] = 0
data['IV for PUT'] =0

# %%
data.head()
# Out:
#    CALLS IV CALLS Bid Qty  CALLS Bid Price  CALLS Ask Price  Strike Price  \
# 0       NaN            75           893.85           906.40         11000
# 1       NaN           300           827.30           874.70         11050
# 2       NaN            75           794.00           807.10         11100
# 3       NaN            75           748.35           758.50         11150
# 4       NaN            75           696.95           706.15         11200
#
#    PUTS Bid Price  PUTS Ask Price  PUTS IV  IV for CALL  IV for PUT
# 0            1.85            2.00    28.38            0           0
# 1            1.05            2.35    27.16            0           0
# 2            2.00            2.15    25.84            0           0
# 3            2.25            2.70    25.20            0           0
# 4            2.10            2.25    23.17            0           0

# %% [markdown]
# # using mibian library
# #BS([underlyingPrice, strikePrice, interestRate, daysToExpiration], volatility=x, callPrice=y, putPrice=z)

# %%
S0 = 11890
K = np.array(data['Strike Price'])
C_Market = np.array(data['CALLS Ask Price'])
P_Market = np.array(data['PUTS Ask Price'])
r = 0.06/252
T = 5
IV_CALL = np.array(data['IV for CALL'])
IV_PUT = np.array(data['IV for PUT'])
i = 0

# %%
for i in range(len(data)):
    IV_CALL[i] = mb.BS([S0 , K[i],r, T],callPrice = C_Market[i]).impliedVolatility
    IV_PUT[i] = mb.BS([S0 , K[i],r, T],putPrice = P_Market[i]).impliedVolatility

# %%
import matplotlib.pyplot as plt
plt.scatter(K , IV_CALL)
plt.xlabel('StrikePrice')
plt.ylabel('Implied Volatality')
plt.title('Implied_Volatality for Call Option')
plt.show()

# %%
data['IV for CALL'] = pd.DataFrame(IV_CALL)

# %%
plt.scatter(K , IV_PUT)
plt.xlabel('StrikePrice')
plt.ylabel('Implied Volatality')
plt.title('Implied_Volatality for PUT Option')
plt.show()

# %%
data['IV for PUT'] = pd.DataFrame(IV_PUT)

# %%
data
# Out:
#     CALLS IV CALLS Bid Qty  CALLS Bid Price  CALLS Ask Price  Strike Price  \
# 0        NaN            75           893.85           906.40         11000
# 1        NaN           300           827.30           874.70         11050
# 2        NaN            75           794.00           807.10         11100
# 3        NaN            75           748.35           758.50         11150
# 4        NaN            75           696.95           706.15         11200
# 5        NaN         1,125           576.85           717.95         11250
# 6        NaN            75           597.80           607.50         11300
# 7        NaN            75           547.70           558.70         11350
# 8        NaN           375           499.80           507.90         11400
# 9        NaN            75           449.05           458.85         11450
# 10       NaN           150           401.05           408.95         11500
# 11       NaN            75           351.75           360.20         11550
# 12       NaN            75           303.60           309.00         11600
# 13       NaN            75           255.80           261.80         11650
# 14       NaN            75           212.30           218.55         11700
# 15      9.05            75           167.00           178.20         11750
# 16     10.51            75           135.70           140.00         11800
# 17     10.85            75           104.05           107.00         11850
# 18     11.22           525            78.20            79.35         11900
# 19     11.61            75            55.05            56.40         11950
# 20     11.66         1,275            38.00            39.00         12000
# 21     11.85            75            24.55            25.15         12050
# 22     11.95            75            15.60            15.85         12100
# 23     12.07           750             9.35             9.60         12150
# 24     12.17           675             5.60             5.65         12200
# 25     12.46         1,575             3.10             3.40         12250
# 26     12.80         4,425             2.10             2.40         12300
# 27     13.15            75             1.00             1.05         12350
# 28     14.57         4,425             1.40             1.60         12400
# 29     15.99            75             1.30            17.95         12450
# 30     16.41         4,875             1.00             1.05         12500
# 31       NaN         2,400             0.55             1.65         12550
# 32     18.40         4,275             0.90             0.95         12600
# 33       NaN         1,800             0.05             1.20         12650
# 34     20.67         8,325             0.85             0.90         12700
# 35       NaN           750             0.10             1.00         12750
# 36     22.41           300             0.70             0.75         12800
# 37       NaN           750             0.10             1.00         12850
# 38     23.48            75             0.50             0.75         12900
# 39       NaN           750             0.10             0.95         12950
#
#     PUTS Bid Price  PUTS Ask Price  PUTS IV  IV for CALL  IV for PUT
# 0             1.85            2.00    28.38           43          30
# 1             1.05            2.35    27.16           50          29
# 2             2.00            2.15    25.84           40          27
# 3             2.25            2.70    25.20           38          26
# 4             2.10            2.25    23.17           35          24
# 5             2.05            2.55    22.16           54          23
# 6             2.70            2.90    21.13           32          22
# 7             2.65            4.00    19.97           30          21
# 8             3.50            3.65    18.98           27          19
# 9             3.55            3.95    17.47           26          18
# 10            4.60            4.80    16.49           24          17
# 11            5.35            5.60    15.33           22          15
# 12            6.80            7.25    14.64           19          14
# 13            9.25            9.45    13.72           17          13
# 14           15.30           15.85    13.78           17          13
# 15           23.30           23.90    13.50           16          13
# 16           36.00           36.90    13.56           15          13
# 17           52.30           55.00    14.02           15          13
# 18           75.85           79.00    14.48           15          13
# 19          100.45          105.00    14.22           14          12
# 20          135.05          139.55    15.20           14          12
# 21          169.15          175.95    14.54           14          12
# 22          210.70          217.95    15.01           14          11
# 23          254.25          265.90    20.41           14          12
# 24          300.85          308.75    16.71           14           0
# 25          306.70          398.90      NaN           14          27
# 26          396.50          404.90    21.12           15           0
# 27          425.50          496.60      NaN           14          31
# 28          495.95          507.60    33.62           17           0
# 29          544.40          569.75    23.74           29          25
# 30          595.20          601.00    30.57           18           0
# 31          593.60          721.85      NaN           21          48
# 32          677.25          720.40      NaN           21          31
# 33          705.85          832.45      NaN           22          55
# 34          776.95          820.50      NaN           23          34
# 35          796.30          942.30      NaN           24          62
# 36          876.80          920.35      NaN           25          37
# 37          887.10         1051.30      NaN           27          69
# 38          927.20         1105.20      NaN           27          72
# 39          992.85         1154.05      NaN           29          74
